# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakhi-Rajpoot/Placement-Prediction/blob/main/Placement_Prediction_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sameerprogrammer/college-placement
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sameerprogrammer/college-placement
# License(s): MIT
# ...
#   0% 0.00/741 [00:00<?, ?B/s]
# 100% 741/741 [00:00<00:00, 1.68MB/s]

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/college-placement.zip')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# 5            5   7.1   48.0          1
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [99 rows x 4 columns]

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# 5            5   7.1   48.0          1
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [99 rows x 4 columns]

# %%
df = pd.read_csv('/content/college-placement.zip')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'], c = df['placement'])

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_test_split(X,Y,test_size=0.1)
# Out:
# [    cgpa     iq
#  64   7.0   64.0
#  38   6.5  160.0
#  75   4.8  169.0
#  65   8.1  166.0
#  45   6.0   66.0
#  ..   ...    ...
#  66   6.9   96.0
#  27   6.0  124.0
#  61   7.3  137.0
#  12   5.4  139.0
#  99   6.2  113.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  95   4.3  200.0
#  34   4.8  163.0
#  20   6.6  120.0
#  25   5.0   91.0
#  31   3.9  109.0
#  14   6.1  103.0
#  21   7.1  151.0
#  90   7.3   86.0
#  50   3.5  233.0
#  17   3.3  183.0,
#  64    1
#  38    1
#  75    0
#  65    1
#  45    1
#       ..
#  66    1
#  27    1
#  61    1
#  12    0
#  99    1
#  Name: placement, Length: 90, dtype: int64,
#  95    0
#  34    0
#  20    1
#  25    0
#  31    0
#  14    0
#  21    1
#  90    1
#  50    0
#  17    0
#  Name: placement, dtype: int64]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 98   6.3  103.0
# 53   8.3  168.0
# 80   4.9  196.0
# 30   7.6  128.0
# 62   6.0  102.0
# ..   ...    ...
# 50   3.5  233.0
# 1    5.9  106.0
# 23   4.7   87.0
# 64   7.0   64.0
# 66   6.9   96.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 98    1
# 53    1
# 80    0
# 30    1
# 62    0
#      ..
# 50    0
# 1     0
# 23    0
# 64    1
# 66    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 4    5.8  142.0
# 99   6.2  113.0
# 83   7.5  130.0
# 44   7.5   61.0
# 78   6.1   81.0
# 40   4.9  134.0
# 47   5.2  161.0
# 86   5.1  128.0
# 26   7.0  199.0
# 93   6.8  112.0

# %%
Y_test
# Out:
# 4     0
# 99    1
# 83    1
# 44    1
# 78    0
# 40    0
# 47    0
# 86    0
# 26    1
# 93    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.2880756 , -0.50683364],
#        [ 2.01652921,  1.11603268],
#        [-0.92184192,  1.81511356],
#        [ 1.41157044,  0.11734572],
#        [ 0.02880756, -0.53180081],
#        [-1.35395532,  0.64165638],
#        [ 0.89303436,  1.2908029 ],
#        [ 0.89303436,  0.39198463],
#        [ 0.11523024,  0.81642659],
#        [-0.92184192, -0.08239167],
#        [-1.69964605, -1.20591451],
#        [-0.92184192,  0.79145942],
#        [ 1.41157044, -0.85637407],
#        [ 1.1523024 , -0.9312756 ],
#        [-0.66257388,  0.21721442],
#        [ 0.11523024,  0.21721442],
#        [-0.66257388, -0.33206342],
#        [ 1.58441581, -0.23219472],
#        [-0.5761512 , -0.0574245 ],
#        [ 0.54734364,  0.36701746],
#        [ 0.54734364, -0.08239167],
#        [ 0.2880756 ,  0.11734572],
#        [ 1.84368385,  1.06609834],
#        [ 0.02880756, -1.95492974],
#        [ 0.46092096, -2.15466713],
#        [ 0.89303436, -0.28212907],
#        [ 0.02880756,  0.01747702],
# ...

# %%
X_test= scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.1440378 ,  0.46688616],
#        [ 0.20165292, -0.25716189],
#        [ 1.32514776,  0.16728007],
#        [ 1.32514776, -1.55545495],
#        [ 0.11523024, -1.05611147],
#        [-0.92184192,  0.26714876],
#        [-0.66257388,  0.94126247],
#        [-0.74899656,  0.11734572],
#        [ 0.89303436,  1.89001508],
#        [ 0.720189  , -0.28212907]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 4     0
# 99    1
# 83    1
# 44    1
# 78    0
# 40    0
# 47    0
# 86    0
# 26    1
# 93    1
# Name: placement, dtype: int64

# %%
Y_pred
# Out:
# array([0, 1, 1, 1, 1, 0, 0, 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values , clf = clf, legend=2)
# Out:
# <Axes: >
